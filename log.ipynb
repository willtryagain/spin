# %% [markdown]
# Model v1
# {
#   "l2_reg": 0,
#   "n_layers": 4,
#   "test_mse": 0.6315945386886597,
#   "train_mae": 0.2780003547668457,
#   "temporal_self_attention": true,
#   "epoch": 138,
#   "n_hops": 2,
#   "dropout": 0.2,
#   "workers": 0,
#   "train_loss": 0.27774578332901,
#   "output_size": null,
#   "grad_clip_val": 5,
#   "val_mse": null,
#   "train_mre": 1.0919475555419922,
#   "_timestamp": 1704976230.1421664,
#   "hidden_size": 512,
#   "config": "imputation/mtst.yaml",
#   "epochs": 300,
#   "val_len": 0.1,
#   "val_mre": null,
#   "seed": 653212481,
#   "_step": 279,
#   "seq_len": 280,
#   "hpc_exp_number": null,
#   "window": 280,
#   "train_mse": 0.37293678522109985,
#   "lr_scheduler": "cyc",
#   "prediction_loss_weight": 1,
#   "num_encoders": 3,
#   "scale_target": false,
#   "lr": 0.001,
#   "stride": 1,
#   "loss_fn": "l1_loss",
#   "batches_epoch": 300,
#   "patience": 80,
#   "reweight": "softmax",
#   "dataset_name": "la_point",
#   "mask_scaling": true,
#   "batch_inference": 20,
#   "test_len": 0.2,
#   "test_mre": 2.9976229667663574,
#   "test_loss": 0.3973251879215241,
#   "adj_threshold": 0.1,
#   "max_edges_subgraph": 1000,
#   "num_mtst_ff_layers": 3,
#   "precision": 16,
#   "model_name": "mtst",
#   "split_batch_in": 1,
#   "n_roots_subgraph": null,
#   "horizon_lag": 1,
#   "eta": 3,
#   "u_size": null,
#   "val_mae": null,
#   "batch_size": 8,
#   "window_lag": 1,
#   "_wandb.runtime": 10001,
#   "test_mae": 0.3912334144115448,
#   "whiten_prob": [
#     0.2,
#     0.5,
#     0.8
#   ],
#   "message_layers": 1,
#   "cut_edges_uniformly": false,
#   "trainer/global_step": 41700,
#   "norm": true,
#   "_runtime": 10002.293446302414,
#   "val_loss": null,
#   "node_index": 0
# }

# %% [markdown]
# Model v2
# {
#   "l2_reg": 0,
#   "n_layers": 3,
#   "n_hops": 2,
#   "dropout": 0.2,
#   "grad_clip_val": 5,
#   "hidden_size": 512,
#   "config": "imputation/mtst.yaml",
#   "epochs": 300,
#   "val_len": 0.1,
#   "val_mre": null,
#   "seq_len": 280,
#   "window": 280,
#   "lr_scheduler": "cyc",
#   "prediction_loss_weight": 1,
#   "num_encoders": 3,
#   "scale_target": false,
#   "lr": 0.001,
#   "stride": 1,
#   "loss_fn": "l1_loss",
#   "batches_epoch": 300,
#   "patience": 80,
#   "reweight": "softmax",
#   "dataset_name": "la_point",
#   "mask_scaling": true,
#   "batch_inference": 20,
#   "test_len": 0.2,
#   "adj_threshold": 0.1,
#   "max_edges_subgraph": 1000,
#   "num_mtst_ff_layers": 3,
#   "precision": 16,
#   "model_name": "mtst",
#   "split_batch_in": 1,
#   "n_roots_subgraph": null,
#   "horizon_lag": 1,
#   "eta": 3,
#   "u_size": null,
#   "val_mae": null,
#   "batch_size": 8,
#   "window_lag": 1,
#   "whiten_prob": [
#     0.2,
#     0.5,
#     0.8
#   ],
#   "message_layers": 1,
#   "cut_edges_uniformly": false,
#   "norm": true,
#   "node_index": 0
# }
